# %%
import requests
# from config_weather_api_key import api_key
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import json
import time
import hvplot.pandas

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# %%
# Read the CSV file
df = pd.read_csv("../Data/clean_UFO.csv")

#View the first 5 rows 
df.head()
# Out:
#              Date_time        city state/province country UFO_shape  \
# 0  1949-10-10 20:30:00  san marcos             tx      us  cylinder
# 1  1956-10-10 21:00:00        edna             tx      us    circle
# 2  1960-10-10 20:00:00     kaneohe             hi      us     light
# 3  1961-10-10 19:00:00     bristol             tn      us    sphere
# 4  1965-10-10 23:45:00     norwalk             ct      us      disk
#
#    length_of_encounter_seconds  \
# 0                       2700.0
# 1                         20.0
# 2                        900.0
# 3                        300.0
# 4                       1200.0
#
#                                          description   latitude   longitude  \
# 0  This event took place in early fall around 194...  29.883056  -97.941111
# 1  My older brother and twin sister were leaving ...  28.978333  -96.645833
# 2  AS a Marine 1st Lt. flying an FJ4B fighter/att...  21.418056 -157.803611
# ...

# %%
df.nunique()
# Out:
# Date_time                      55652
# city                           11235
# state/province                    52
# country                            1
# UFO_shape                         19
# length_of_encounter_seconds      460
# description                    63321
# latitude                       11495
# longitude                      12293
# year                              83
# month                             12
# is_weekend                         2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63553 entries, 0 to 63552
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date_time                    63553 non-null  object
#  1   city                         63553 non-null  object
#  2   state/province               63553 non-null  object
#  3   country                      63553 non-null  object
#  4   UFO_shape                    63553 non-null  object
#  5   length_of_encounter_seconds  63553 non-null  float64
#  6   description                  63553 non-null  object
#  7   latitude                     63553 non-null  float64
#  8   longitude                    63553 non-null  float64
#  9   year                         63553 non-null  int64
#  10  month                        63553 non-null  int64
#  11  is_weekend                   63553 non-null  bool
# dtypes: bool(1), float64(3), int64(2), object(6)
# ...

# %%
# test the endpoint 
# url =f"http://api.openweathermap.org/geo/1.0/direct?q=London&limit=5&appid={api_key}"

# %%
# display the data 

# response=requests.get(url)
# print (response.status_code)

# data= response.json()
# data

# %%
# dropping columns 
df_city = df.drop (['Date_time'],axis=1)
df_city
# Out:
#              city state/province country UFO_shape  \
# 0      san marcos             tx      us  cylinder
# 1            edna             tx      us    circle
# 2         kaneohe             hi      us     light
# 3         bristol             tn      us    sphere
# 4         norwalk             ct      us      disk
# ...           ...            ...     ...       ...
# 63548   nashville             tn      us     light
# 63549       boise             id      us    circle
# 63550        napa             ca      us     other
# 63551      vienna             va      us    circle
# 63552      edmond             ok      us     cigar
#
#        length_of_encounter_seconds  \
# 0                           2700.0
# 1                             20.0
# 2                            900.0
# 3                            300.0
# 4                           1200.0
# ...                            ...
# 63548                        600.0
# 63549                       1200.0
# ...

# %%
df_city = df.drop (['country','Date_time','UFO_shape','length_of_encounter_seconds','description','year','month','is_weekend'],axis=1)
df_city.value_counts()
# Out:
# city                                                       state/province  latitude   longitude
# seattle                                                    wa              47.606389  -122.330833    471
# phoenix                                                    az              33.448333  -112.073333    434
# las vegas                                                  nv              36.175000  -115.136389    352
# los angeles                                                ca              34.052222  -118.242778    347
# san diego                                                  ca              32.715278  -117.156389    327
#                                                                                                     ...
# middlefield (on county line&#44 geauga_trumbull counties)  oh              41.461944  -81.073889       1
# middlefield                                                oh              41.461944  -81.073889       1
# ...

# %%
# Make a bar chart for number of sightings per city

# init the plot
plt.figure(figsize=(10,6))
plt.bar(x_axis, users, color='firebrick', alpha=0.5, align="center")

# customize the plot
plt.xlim(-0.75, 4.75)
plt.ylim(0, 60000)

plt.title("Popularity of Programming Languages", fontsize=16, fontweight="bold")
plt.xlabel("Programming Language", fontsize=12)
plt.ylabel("Number of People Using Programming Languages", fontsize=12)

plt.grid(axis="y", c="lightgray", linestyle="dashed", alpha=0.4)

# show the plot
plt.show()

# %%
# df_uniquecity = df_city.drop_duplicates(subset=["city"], keep='first')
# df_uniquecity
# Out:
#                                         city   latitude   longitude
# 0                                 san marcos  29.883056  -97.941111
# 1                                       edna  28.978333  -96.645833
# 2                                    kaneohe  21.418056 -157.803611
# 3                                    bristol  36.595000  -82.188889
# 4                                    norwalk  41.117500  -73.408333
# ...                                      ...        ...         ...
# 63478                               mountain  45.184722  -88.473611
# 63488                    spanaway (south of)  47.104167 -122.433333
# 63499                                lemitar  34.159722 -106.909722
# 63503                         double springs  34.146389  -87.402222
# 63540  buffalo (west of; on highway 90 west)  42.886389  -78.878611
#
# [11235 rows x 3 columns]

# %%
# Create a dictionary containing coordinates
coordinates = {
    "latitude": [29.883056,28.978333],
    "longitude": [
        -97.941111,-96.645833],
    "City": ["san marcos",'edna'],
#     "Population": [2099530, 4637436, 2495825]
}

# %%
# Create a Pandas DataFrame containing coordinates
coordinates_df = pd.DataFrame(coordinates)

# Display sample data
coordinates_df
# Out:
#     latitude  longitude        City
# 0  29.883056 -97.941111  san marcos
# 1  28.978333 -96.645833        edna

# %%
# Configure the map plot_1
map_plot_1 = coordinates_df.hvplot.points(
    "longitude",
    "latitude",
    geo = True,
    tiles = "OSM",
    scale= 5,
    frame_width = 700,
    frame_height = 500,
    size=5
)

# Display the map plot_1
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [longitude,latitude]

# %%
long_list = df_uniquecity['longitude'].values.tolist()
long_list
# Out:
# [-97.9411111,
#  -96.6458333,
#  -157.8036111,
#  -82.1888889,
#  -73.4083333,
#  -86.2861111,
#  -82.9841667,
#  -118.3516667,
#  -82.7344444,
#  -73.5275,
#  -83.7619444,
#  -80.2536111,
#  -83.3219444,
#  -83.2330556,
#  -72.1936111,
#  -71.5666667,
#  -79.975,
#  -122.3522222,
#  -98.4933333,
#  -85.7594444,
#  -73.7133333,
#  -73.9213889,
#  -117.1563889,
#  -104.7425,
#  -95.3630556,
#  -96.8,
#  -85.6205556,
#  -73.7633333,
#  -87.9063889,
#  -70.2830556,
#  -105.27,
#  -122.3308333,
#  -118.6375,
#  -122.9530556,
#  -83.6533333,
#  -75.6288889,
#  -76.8847222,
#  -85.6602778,
#  -95.5575,
#  -83.7247222,
#  -97.7969444,
#  -89.5888889,
#  -85.9516667,
#  -73.8955556,
#  -91.9922222,
#  -93.7169444,
#  -79.9311111,
#  -84.3622222,
#  -85.1411111,
#  -111.8219444,
#  -83.5961111,
#  -92.9744444,
#  -118.3258333,
#  -112.0733333,
#  -88.2811111,
#  -115.1363889,
#  -117.425,
#  -80.8102778,
#  -84.5533333,
#  -122.1330556,
#  -94.6272222,
#  -119.1361111,
#  -122.0797222,
# ...

# %%
lat_list = df_uniquecity['latitude'].values.tolist()
lat_list
# Out:
# [29.8830556,
#  28.9783333,
#  21.4180556,
#  36.595,
#  41.1175,
#  33.5861111,
#  30.2947222,
#  33.9163889,
#  35.2333333,
#  40.6686111,
#  37.1536111,
#  35.8238889,
#  36.8430556,
#  42.5377778,
#  41.3252778,
#  42.3916667,
#  32.8544444,
#  45.5827778,
#  29.4238889,
#  38.2541667,
#  40.7008333,
#  41.7002778,
#  32.7152778,
#  38.7583333,
#  29.7630556,
#  32.7833333,
#  44.7630556,
#  41.0338889,
#  43.0388889,
#  43.9627778,
#  40.015,
#  47.6063889,
#  34.1577778,
#  46.7163889,
#  31.7058333,
#  35.235,
#  40.2736111,
#  30.1586111,
#  29.6158333,
#  35.8905556,
#  32.7591667,
#  40.6936111,
#  36.2522222,
#  42.9097222,
#  34.1027778,
#  39.0725,
#  32.7763889,
#  39.4402778,
#  39.6411111,
#  33.4222222,
#  32.5436111,
#  43.6666667,
#  34.0983333,
#  33.4483333,
#  42.0372222,
#  36.175,
#  47.6588889,
#  35.5847222,
#  35.265,
#  38.0194444,
#  39.1141667,
#  46.2113889,
#  37.6688889,
#  37.6447222,
#  41.6916667,
#  44.8838889,
#  37.7241667,
#  26.525,
# ...

# %%
city_name = df_uniquecity['city'].values.tolist()
city_name
# Out:
# ['san marcos',
#  'edna',
#  'kaneohe',
#  'bristol',
#  'norwalk',
#  'pell city',
#  'live oak',
#  'hawthorne',
#  'brevard',
#  'bellmore',
#  'manchester',
#  'lexington',
#  'harlan county',
#  'west bloomfield',
#  'niantic',
#  'hudson',
#  'north charleston',
#  'washougal',
#  'san antonio',
#  'louisville',
#  'elmont',
#  'poughkeepsie',
#  'san diego',
#  'security',
#  'houston',
#  'dallas',
#  'traverse city',
#  'white plains',
#  'milwaukee',
#  'new gloucester',
#  'boulder',
#  'seattle (ballard area)',
#  'calabasas',
#  'centralia',
#  'ashburn',
#  'frisco',
#  'harrisburg',
#  'panama city',
#  'stafford',
#  'seymour',
#  'weatherford',
#  'peoria',
#  'carthage',
#  'burnt hills',
#  'pinebergen',
#  'higginsville',
#  'charleston',
#  'monroe county',
#  'connersville',
#  'mesa',
#  'bonaire',
#  'austin',
#  'hollywood',
#  'phoenix (north part)',
#  'elgin',
#  'las vegas',
#  'spokane (about 30 miles sw of&#44i-90&#44 maybe mm 254)',
#  'mooresville',
# ...

# %%
# Create a dictionary containing coordinates
city_coordinates = pd.DataFrame(['long_list'],['lat_list'],['lat_list'])
city_coordinates
# Out:
#            lat_list
# lat_list  long_list

# %%
dict = {'long': long_list, 'lat': lat_list, 'cities': city_name}
df_final=pd.DataFrame(dict)
df_final
# Out:
#              long        lat                                 cities
# 0      -97.941111  29.883056                             san marcos
# 1      -96.645833  28.978333                                   edna
# 2     -157.803611  21.418056                                kaneohe
# 3      -82.188889  36.595000                                bristol
# 4      -73.408333  41.117500                                norwalk
# ...           ...        ...                                    ...
# 11230  -88.473611  45.184722                               mountain
# 11231 -122.433333  47.104167                    spanaway (south of)
# 11232 -106.909722  34.159722                                lemitar
# 11233  -87.402222  34.146389                         double springs
# 11234  -78.878611  42.886389  buffalo (west of; on highway 90 west)
#
# [11235 rows x 3 columns]
